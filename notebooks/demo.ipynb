# %%
# Add relevant Jupyter notebook extensions 
import os

#why does it not work without this???????????
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [autoreload of uuv_mission.dynamic failed: Traceback (most recent call last):
#   File "c:\Users\tarse\.venvs\.venv\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\tarse\.venvs\.venv\Lib\site-packages\IPython\extensions\autoreload.py", line 475, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "C:\Users\tarse\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ...

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['C:\\Users\\tarse\\AppData\\Local\\Programs\\Python\\Python311\\python311.zip', 'C:\\Users\\tarse\\AppData\\Local\\Programs\\Python\\Python311\\DLLs', 'C:\\Users\\tarse\\AppData\\Local\\Programs\\Python\\Python311\\Lib', 'C:\\Users\\tarse\\AppData\\Local\\Programs\\Python\\Python311', 'c:\\Users\\tarse\\.venvs\\.venv', '', 'c:\\Users\\tarse\\.venvs\\.venv\\Lib\\site-packages', 'C:\\Users\\tarse\\OneDrive - Nexus365\\Uni work\\Year 3\\B1 Engineering Computation\\Scientific Coding\\b1-coding-practical-mt24', 'c:\\Users\\tarse\\.venvs\\.venv\\Lib\\site-packages\\win32', 'c:\\Users\\tarse\\.venvs\\.venv\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\tarse\\.venvs\\.venv\\Lib\\site-packages\\Pythonwin']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
from uuv_mission import Submarine, ClosedLoop, Mission

sub = Submarine()
# Instantiate your controller (depending on your implementation)
closed_loop = ClosedLoop(sub, 1)
mission = Mission.from_csv("C:/Users/tarse/OneDrive - Nexus365/Uni work/Year 3/B1 Engineering Computation/Scientific Coding/b1-coding-practical-mt24/data/mission.csv")  # Provide the correct path to the CSV file

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
